# %% [markdown]
# # Подготовка данных

# %%
import pandas as pd
import numpy as np

import optuna
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Загружаем датасет

# %%
full_path = "loan_data.csv"

df = pd.read_csv(full_path)
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.08                         2.0           504
# 2                 0.44                         3.0           635
# 3                 0.44                         2.0           675
# 4                 0.53                         4.0           586
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1
# 1                            Yes            0
# 2                             No            1
# 3                             No            1
# 4                             No            1

# %% [markdown]
# ### Предобработка датасета

# %%
num_cols = df.select_dtypes("number").columns[:-1]
cat_cols = df.select_dtypes("object").columns

scaler = StandardScaler()
le = LabelEncoder()

df[num_cols] = scaler.fit_transform(df[num_cols])

for col in cat_cols:
    df[col] = le.fit_transform(df[col])

df.head()
# Out:
#    person_age  person_gender  person_education  person_income  person_emp_exp  \
# 0   -0.953538              0                 4      -0.104090       -0.892284
# 1   -1.118963              0                 3      -0.846005       -0.892284
# 2   -0.457264              0                 3      -0.844065       -0.397517
# 3   -0.788113              0                 1      -0.007039       -0.892284
# 4   -0.622689              1                 4      -0.176371       -0.727362
#
#    person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0                      3   4.024953            4       1.683039
# 1                      2  -1.359209            1       0.044782
# 2                      0  -0.646600            3       0.625557
# 3                      3   4.024953            3       1.417829
# 4                      3   4.024953            3       1.095549
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0             4.016394                   -0.739109     -1.419814
# 1            -0.684829                   -0.996863     -2.549975
# 2             3.443074                   -0.739109      0.047412
# 3             3.443074                   -0.996863      0.840507
# 4             4.475050                   -0.481354     -0.924130
#
#    previous_loan_defaults_on_file  loan_status
# 0                               0            1
# 1                               1            0
# 2                               0            1
# 3                               0            1
# 4                               0            1

# %%
X = df.drop(columns='loan_status').values
y = df["loan_status"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Обучение моделей

# %% [markdown]
# ### Подготовка библиотек

# %%
import mlflow
import mlflow.sklearn
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

def get_metrics(y_true, y_pred):
    return {
        "accuracy": accuracy_score(y_true, y_pred),
        "precision_macro": precision_score(y_true, y_pred, average="macro"),
        "recall_macro": recall_score(y_true, y_pred, average="macro"),
        "f1_macro": f1_score(y_true, y_pred, average="macro")
    }

def mlflow_save_model_metrics(model_name, model, best_params):
    with mlflow.start_run(run_name=model_name):

        mlflow.log_params(best_params)

        model = model(**best_params)
        model.fit(X_train, y_train)
        pred = model.predict(X_test)

        metrics = get_metrics(y_test, pred)
        mlflow.log_metrics(metrics)

        mlflow.sklearn.log_model(model, artifact_path=model_name)

        print(f"Логирование модели {model_name} завершено.")

mlflow.set_tracking_uri("file:///C:\\Users\\Михаил\\Proga\\ml\\artsofte\\mlruns")
mlflow.set_experiment("loan status classification")
# Out:
# c:\Users\Михаил\Proga\ml\.venv\Lib\site-packages\mlflow\tracking\_tracking_service\utils.py:177: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance.
#   return FileStore(store_uri, store_uri)
# <Experiment: artifact_location='file:///C:\\Users\\Михаил\\Proga\\ml\\artsofte\\mlruns/167519363609596686', creation_time=1765188905273, experiment_id='167519363609596686', last_update_time=1765188905273, lifecycle_stage='active', name='loan status classification', tags={}>

# %% [markdown]
# ### LogisticRegression

# %%
def objective_logreg(trial, X, y):
    params = {
        "C": trial.suggest_float("C", 1e-4, 10.0, log=True),
        "penalty": trial.suggest_categorical("penalty", ["l2"]),
        "solver": trial.suggest_categorical("solver", ["lbfgs", "liblinear"]),
        "max_iter": 1000
    }

    model = LogisticRegression(**params)
    score = cross_val_score(model, X, y, cv=3, scoring="accuracy").mean()
    return score

study = optuna.create_study(direction="maximize")
study.optimize(lambda trial: objective_logreg(trial, X_train, y_train), n_trials=50)

print(f"Лучшие параметры: {study.best_params}")
print(f"Лучшая accuracy: {study.best_value}")

mlflow_save_model_metrics("LogisticRegression", LogisticRegression, study.best_params)
# Out:
# [I 2025-12-08 17:39:56,014] A new study created in memory with name: no-name-de3761fe-313b-463e-9aef-9e617ef992cf
# [I 2025-12-08 17:39:56,151] Trial 0 finished with value: 0.892388888888889 and parameters: {'C': 1.8403216761015833, 'penalty': 'l2', 'solver': 'lbfgs'}. Best is trial 0 with value: 0.892388888888889.
# [I 2025-12-08 17:39:56,229] Trial 1 finished with value: 0.8670555555555555 and parameters: {'C': 0.0007173668583505726, 'penalty': 'l2', 'solver': 'lbfgs'}. Best is trial 0 with value: 0.892388888888889.
# [I 2025-12-08 17:39:56,307] Trial 2 finished with value: 0.8453888888888889 and parameters: {'C': 0.0003269717747671665, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.892388888888889.
# [I 2025-12-08 17:39:56,403] Trial 3 finished with value: 0.8841111111111112 and parameters: {'C': 0.002081914378378003, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.892388888888889.
# [I 2025-12-08 17:39:56,471] Trial 4 finished with value: 0.7855555555555557 and parameters: {'C': 0.00010481569632471838, 'penalty': 'l2', 'solver': 'lbfgs'}. Best is trial 0 with value: 0.892388888888889.
# [I 2025-12-08 17:39:56,703] Trial 5 finished with value: 0.8923333333333333 and parameters: {'C': 5.746240976896022, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.892388888888889.
# [I 2025-12-08 17:39:56,903] Trial 6 finished with value: 0.8923333333333333 and parameters: {'C': 1.1732602683272777, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.892388888888889.
# [I 2025-12-08 17:39:57,000] Trial 7 finished with value: 0.8845555555555555 and parameters: {'C': 0.0021587222914421695, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.892388888888889.
 'penalty': 'l2', 'solver': 'lbfgs'}. Best is trial 24 with value: 0.8927222222222223.
# [I 2025-12-08 17:40:01,666] Trial 48 finished with value: 0.8893333333333334 and parameters: {'C': 0.004693852515587316, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 24 with value: 0.8927222222222223.
# [I 2025-12-08 17:40:01,778] Trial 49 finished with value: 0.8923888888888888 and parameters: {'C': 0.11115603119063541, 'penalty': 'l2', 'solver': 'lbfgs'}. Best is trial 24 with value: 0.8927222222222223.
# Лучшие параметры: {'C': 0.07501847408607885, 'penalty': 'l2', 'solver': 'lbfgs'}
# Лучшая accuracy: 0.8927222222222223
# 2025/12/08 17:40:02 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Логирование модели LogisticRegression завершено.

# %% [markdown]
# ### RandomForest

# %%
def objective_rf(trial, X, y):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 500),
        "max_depth": trial.suggest_int("max_depth", 2, 30),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2"]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
    }

    model = RandomForestClassifier(**params)

    score = cross_val_score(model, X, y, cv=3, scoring="accuracy").mean()
    return score

study = optuna.create_study(direction="maximize")
study.optimize(lambda trial: objective_rf(trial, X_train, y_train), n_trials=50)

print(f"Лучшие параметры: {study.best_params}")
print(f"Лучшая accuracy: {study.best_value}")

mlflow_save_model_metrics("RandomForest", RandomForestClassifier, study.best_params)
# Out:
# [I 2025-12-08 17:40:09,984] A new study created in memory with name: no-name-db6af92e-387e-46f0-85bc-a68a524ad95d
# [I 2025-12-08 17:40:20,704] Trial 0 finished with value: 0.9267500000000001 and parameters: {'n_estimators': 155, 'max_depth': 22, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.9267500000000001.
# [I 2025-12-08 17:40:43,221] Trial 1 finished with value: 0.9274722222222223 and parameters: {'n_estimators': 312, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 1 with value: 0.9274722222222223.
# [I 2025-12-08 17:41:08,407] Trial 2 finished with value: 0.9268888888888888 and parameters: {'n_estimators': 354, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}. Best is trial 1 with value: 0.9274722222222223.
# [I 2025-12-08 17:41:32,285] Trial 3 finished with value: 0.9261944444444445 and parameters: {'n_estimators': 342, 'max_depth': 22, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': False}. Best is trial 1 with value: 0.9274722222222223.
# [I 2025-12-08 17:41:39,532] Trial 4 finished with value: 0.9267777777777778 and parameters: {'n_estimators': 100, 'max_depth': 19, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': False}. Best is trial 1 with value: 0.9274722222222223.
# [I 2025-12-08 17:41:51,700] Trial 5 finished with value: 0.918 and parameters: {'n_estimators': 396, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 1 with value: 0.9274722222222223.
# [I 2025-12-08 17:42:11,971] Trial 6 finished with value: 0.9276944444444445 and parameters: {'n_estimators': 266, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}. Best is trial 6 with value: 0.9276944444444445.
# [I 2025-12-08 17:42:18,488] Trial 7 finished with value: 0.9234166666666667 and parameters: {'n_estimators': 138, 'max_depth': 16, 'min_samples_split': 16, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 6 with value: 0.9276944444444445.
# [I 2025-12-08 17:42:30,274] Trial 8 finished with value: 0.9203888888888888 and parameters: {'n_estimators': 311, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': True}. Best is trial 6 with value: 0.9276944444444445.
# [I 2025-12-08 17:42:39,728] Trial 9 finished with value: 0.9242222222222222 and parameters: {'n_estimators': 196, 'max_depth': 24, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap
 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 30 with value: 0.9284722222222221.
# [I 2025-12-08 17:55:30,420] Trial 49 finished with value: 0.9237777777777777 and parameters: {'n_estimators': 319, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 30 with value: 0.9284722222222221.
# Лучшие параметры: {'n_estimators': 328, 'max_depth': 21, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}
# Лучшая accuracy: 0.9284722222222221
# 2025/12/08 17:55:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Логирование модели RandomForest завершено.

# %% [markdown]
# ### Gradient Boosting

# %%
def objective_gb(trial, X, y):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 400),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.5),
        "max_depth": trial.suggest_int("max_depth", 2, 10),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 20),
    }

    model = GradientBoostingClassifier(**params)

    score = cross_val_score(model, X, y, cv=3, scoring="accuracy").mean()
    return score

study = optuna.create_study(direction="maximize")
study.optimize(lambda trial: objective_gb(trial, X_train, y_train), n_trials=50)

print(f"Лучшие параметры: {study.best_params}")
print(f"Лучшая accuracy: {study.best_value}")

mlflow_save_model_metrics("GradBoost", GradientBoostingClassifier, study.best_params)
# Out:
# [I 2025-12-08 17:55:47,985] A new study created in memory with name: no-name-d268302f-38fb-4bcd-82ce-53490993ae8e
# [I 2025-12-08 17:56:10,627] Trial 0 finished with value: 0.924 and parameters: {'n_estimators': 178, 'learning_rate': 0.4909350960852229, 'max_depth': 7, 'subsample': 0.5720592363581373, 'min_samples_split': 7, 'min_samples_leaf': 17}. Best is trial 0 with value: 0.924.
# [I 2025-12-08 17:56:25,111] Trial 1 finished with value: 0.928 and parameters: {'n_estimators': 182, 'learning_rate': 0.09612191814117353, 'max_depth': 3, 'subsample': 0.8330933125417772, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.928.
# [I 2025-12-08 17:56:31,785] Trial 2 finished with value: 0.9269166666666667 and parameters: {'n_estimators': 92, 'learning_rate': 0.09980299976150092, 'max_depth': 4, 'subsample': 0.5513557481292535, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 1 with value: 0.928.
# [I 2025-12-08 17:56:42,817] Trial 3 finished with value: 0.9314444444444444 and parameters: {'n_estimators': 59, 'learning_rate': 0.1996816602764131, 'max_depth': 7, 'subsample': 0.901774056302195, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.9314444444444444.
# [I 2025-12-08 17:57:03,407] Trial 4 finished with value: 0.9306944444444444 and parameters: {'n_estimators': 168, 'learning_rate': 0.3588177694646029, 'max_depth': 5, 'subsample': 0.7846446601356267, 'min_samples_split': 17, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.9314444444444444.
# [I 2025-12-08 17:57:07,068] Trial 5 finished with value: 0.9125833333333334 and parameters: {'n_estimators': 64, 'learning_rate': 0.04376158456134795, 'max_depth': 2, 'subsample': 0.8878673362510432, 'min_samples_split': 16, 'min_samples_leaf': 18}. Best is trial 3 with value: 0.9314444444444444.
# [I 2025-12-08 17:57:38,455] Trial 6 finished with value: 0.929611111111111 and parameters: {'n_estimators': 265, 'learning_rate': 0.49863725915363355, 'max_depth': 4, 'subsample': 0.981995410124007, 'min_samples_split': 16, 'min_samples_leaf': 7}. Best is trial 3 with value: 0.9314444444444444.
# [I 2025-12-08 17:58:45,872] Trial 7 finished with value: 0.9334722222222221 and parameters: {'n_estimators': 373, 'learning_rate': 0.14440836190270218, 'max_depth': 9, 'subsample': 0.663035681293886, 'min_samples_split': 11, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.9334722222222221.
# [I 2025-12-08 17:58:53,172] Trial 8 finished with value: 0.9109444444444446 and parameters: {'n_estimators': 67, 'learning_rate': 0.01263810774383157, 'max_depth': 6, 'subsample': 0.9001845289687725, 'min_samples_split': 3, 'min_samples_leaf': 16}. Best is trial 7 with value: 0.9334722222222221.
# [I 2025-12-08 17:59:05,066] Trial 9 finished with value: 0.93025 and parameters: {'n_estimators': 208, 'learning_rate': 0.12698095000306037, 'max_depth': 3, 'subsample': 0.5573308215517057, 'min_samples_split': 17, 'min_samples_leaf': 13}. Best is trial 7 with value: 0.9334722222222221.
# [I 2025-12-08 18:00:16,396] Trial 10 finished with value: 0.9324166666666667 and parameters: {'n_estimators': 398, 'learning_rate': 0.29606823899480716, 'max_depth': 10, 'subsample': 0.6454859990245662, 'min_samples_split': 13, 'min_samples_leaf': 10}. Best is trial 7 with value: 0.9334722222222221.
# [I 2025-12-08 18:01:31,136] Trial 11 finished with value: 0.9328888888888889 and parameters: {'n_estimators': 390, 'learning_rate': 0.2936896264024259, 'max_depth': 10, 'subsample': 0.6761259732832189, 'min_samples_split': 13, 'min_samples_leaf': 10}. Best is trial 7 with value: 0.9334722222222221.
# [I 2025-12-08 18:02:49,574] Trial 12 finished with value: 0.9336111111111111 and parameters: {'n_estimators': 390, 'learning_rate': 0.22722991165615247, 'max_depth': 10, 'subsample': 0.6831547234262266, 'min_samples_split': 13, 'min_samples_leaf': 10}. Best is trial 12 with value: 0.9336111111111111.
# [I 2025-12-08 18:03:50,626] Trial 13 finished with value: 0.9324166666666667 and parameters: {'n_estimators': 320, 'learning_rate': 0.20303961138353122, 'max_depth': 9, 'subsample': 0.7002423120494787, 'min_samples_split': 20, 'min_samples_leaf': 13}. Best is trial 12 with value: 0.9336111111111111.
# [I 2025-12-08 18:04:52,122] Trial 14 finished with value: 0.9340555555555556 and parameters: {'n_estimators': 334, 'learning_rate': 0.1929029022214599, 'max_depth': 8, 'subsample': 0.7546737165392544, 'min_samples_split': 12, 'min_samples_leaf': 20}. Best is trial 14 with value: 0.9340555555555556.
# [I 2025-12-08 18:05:50,214] Trial 15 finished with value: 0.9335000000000001 and parameters: {'n_estimators': 320, 'learning_rate': 0.2190805007837237, 'max_depth': 8, 'subsample': 0.7598853751736074, 'min_samples_split': 14, 'min_samples_leaf': 20}. Best is trial 14 with value: 0.9340555555555556.
# [I 2025-12-08 18:06:46,470] Trial 16 finished with value: 0.9307777777777777 and parameters: {'n_estimators': 331, 'learning_rate': 0.362371983469597, 'max_depth': 8, 'subsample': 0.7166814651968665, 'min_samples_split': 8, 'min_samples_leaf': 13}. Best is trial 14 with value: 0.9340555555555556.
# [I 2025-12-08 18:07:29,579] Trial 17 finished with value: 0.9300833333333333 and parameters: {'n_estimators': 263, 'learning_rate': 0.2583770807682561, 'max_depth': 9, 'subsample': 0.6208747992018416, 'min_samples_split': 6, 'min_samples_leaf': 8}. Best is trial 14 with value: 0.9340555555555556.
# [I 2025-12-08 18:08:45,630] Trial 18 finished with value: 0.9327222222222223 and parameters: {'n_estimators': 350, 'learning_rate': 0.36025063090876763, 'max_depth': 10, 'subsample': 0.7868807015516184, 'min_samples_split': 20, 'min_samples_leaf': 15}. Best is trial 14 with value: 0.9340555555555556.
# [I 2025-12-08 18:09:41,611] Trial 19 finished with value: 0.9338055555555557 and parameters: {'n_estimators': 283, 'learning_rate': 0.16304034558273872, 'max_depth': 8, 'subsample': 0.842231791429681, 'min_samples_split': 14, 'min_samples_leaf': 20}. Best is trial 14 with value: 0.9340555555555556.
# [I 2025-12-08 18:10:29,450] Trial 20 finished with value: 0.9342222222222222 and parameters: {'n_estimators': 277, 'learning_rate': 0.16288263168761238, 'max_depth': 7, 'subsample': 0.839041523324532, 'min_samples_split': 10, 'min_samples_leaf': 20}. Best is trial 20 with value: 0.9342222222222222.
# [I 2025-12-08 18:11:18,971] Trial 21 finished with value: 0.9342222222222224 and parameters: {'n_estimators': 278, 'learning_rate': 0.1571182777808469, 'max_depth': 7, 'subsample': 0.8265488172870957, 'min_samples_split': 10, 'min_samples_leaf': 20}. Best is trial 21 with value: 0.9342222222222224.
# [I 2025-12-08 18:12:02,253] Trial 22 finished with value: 0.9345555555555555 and parameters: {'n_estimators': 285, 'learning_rate': 0.1696823259537092, 'max_depth': 6, 'subsample': 0.8354099601532612, 'min_samples_split': 10, 'min_samples_leaf': 19}. Best is trial 22 with value: 0.9345555555555555.
# [I 2025-12-08 18:12:43,444] Trial 23 finished with value: 0.9349722222222222 and parameters: {'n_estimators': 242, 'learning_rate': 0.07233821902341198, 'max_depth': 6, 'subsample': 0.9725853055973849, 'min_samples_split': 10, 'min_samples_leaf': 18}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:13:23,180] Trial 24 finished with value: 0.9347222222222222 and parameters: {'n_estimators': 231, 'learning_rate': 0.07359845612289609, 'max_depth': 6, 'subsample': 0.9964233377825307, 'min_samples_split': 5, 'min_samples_leaf': 18}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:14:03,426] Trial 25 finished with value: 0.9338611111111111 and parameters: {'n_estimators': 236, 'learning_rate': 0.06486284531437227, 'max_depth': 6, 'subsample': 0.9974651393626394, 'min_samples_split': 5, 'min_samples_leaf': 18}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:14:20,767] Trial 26 finished with value: 0.9298333333333334 and parameters: {'n_estimators': 127, 'learning_rate': 0.07076720486682074, 'max_depth': 5, 'subsample': 0.9405807963385822, 'min_samples_split': 5, 'min_samples_leaf': 15}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:14:50,781] Trial 27 finished with value: 0.9293055555555556 and parameters: {'n_estimators': 225, 'learning_rate': 0.03649172328710013, 'max_depth': 5, 'subsample': 0.9497705039015981, 'min_samples_split': 8, 'min_samples_leaf': 18}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:15:30,887] Trial 28 finished with value: 0.934888888888889 and parameters: {'n_estimators': 240, 'learning_rate': 0.10368600947629225, 'max_depth': 6, 'subsample': 0.9455096165034955, 'min_samples_split': 2, 'min_samples_leaf': 15}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:15:54,925] Trial 29 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 171, 'learning_rate': 0.10705387702725835, 'max_depth': 5, 'subsample': 0.9568256359712308, 'min_samples_split': 2, 'min_samples_leaf': 16}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:16:12,014] Trial 30 finished with value: 0.9260277777777777 and parameters: {'n_estimators': 202, 'learning_rate': 0.01335617104453072, 'max_depth': 7, 'subsample': 0.5009829140522513, 'min_samples_split': 4, 'min_samples_leaf': 14}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:16:51,621] Trial 31 finished with value: 0.9346944444444446 and parameters: {'n_estimators': 245, 'learning_rate': 0.07471441038556992, 'max_depth': 6, 'subsample': 0.9175950958863466, 'min_samples_split': 7, 'min_samples_leaf': 17}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:17:31,644] Trial 32 finished with value: 0.9346388888888889 and parameters: {'n_estimators': 247, 'learning_rate': 0.07498327508086504, 'max_depth': 6, 'subsample': 0.9253078563537307, 'min_samples_split': 7, 'min_samples_leaf': 17}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:17:55,454] Trial 33 finished with value: 0.9323055555555554 and parameters: {'n_estimators': 203, 'learning_rate': 0.10594384720170494, 'max_depth': 4, 'subsample': 0.9758995806649353, 'min_samples_split': 2, 'min_samples_leaf': 17}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:18:15,209] Trial 34 finished with value: 0.9328888888888889 and parameters: {'n_estimators': 153, 'learning_rate': 0.11811806528325576, 'max_depth': 5, 'subsample': 0.8751317336004518, 'min_samples_split': 4, 'min_samples_leaf': 12}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:18:51,125] Trial 35 finished with value: 0.9342777777777779 and parameters: {'n_estimators': 221, 'learning_rate': 0.08104750717233358, 'max_depth': 6, 'subsample': 0.9228023368720103, 'min_samples_split': 7, 'min_samples_leaf': 16}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:19:45,025] Trial 36 finished with value: 0.9320833333333334 and parameters: {'n_estimators': 243, 'learning_rate': 0.04299864116876842, 'max_depth': 7, 'subsample': 0.9974389916295607, 'min_samples_split': 6, 'min_samples_leaf': 18}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:20:58,062] Trial 37 finished with value: 0.9335 and parameters: {'n_estimators': 302, 'learning_rate': 0.04402169764175708, 'max_depth': 6, 'subsample': 0.8709133703592434, 'min_samples_split': 3, 'min_samples_leaf': 15}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:21:32,103] Trial 38 finished with value: 0.9322777777777778 and parameters: {'n_estimators': 185, 'learning_rate': 0.44568877592862843, 'max_depth': 4, 'subsample': 0.959247708207314, 'min_samples_split': 9, 'min_samples_leaf': 17}. Best is trial 23 with value: 0.9349722222222222.
# [I 2025-12-08 18:22:27,454] Trial 39 finished with value: 0.9356944444444445 and parameters: {'n_estimators': 250, 'learning_rate': 0.13341750427192753, 'max_depth': 5, 'subsample': 0.9145382124268482, 'min_samples_split': 5, 'min_samples_leaf': 19}. Best is trial 39 with value: 0.9356944444444445.
# [I 2025-12-08 18:22:58,373] Trial 40 finished with value: 0.9326388888888889 and parameters: {'n_estimators': 134, 'learning_rate': 0.127527934424865, 'max_depth': 5, 'subsample': 0.9726841086131723, 'min_samples_split': 4, 'min_samples_leaf': 19}. Best is trial 39 with value: 0.9356944444444445.
# [I 2025-12-08 18:24:11,859] Trial 41 finished with value: 0.9350833333333334 and parameters: {'n_estimators': 259, 'learning_rate': 0.08809086275073282, 'max_depth': 7, 'subsample': 0.9204461615028332, 'min_samples_split': 6, 'min_samples_leaf': 19}. Best is trial 39 with value: 0.9356944444444445.
# [I 2025-12-08 18:25:22,592] Trial 42 finished with value: 0.9358888888888889 and parameters: {'n_estimators': 254, 'learning_rate': 0.09679919387889922, 'max_depth': 7, 'subsample': 0.8907630149846777, 'min_samples_split': 5, 'min_samples_leaf': 19}. Best is trial 42 with value: 0.9358888888888889.
# [I 2025-12-08 18:26:41,914] Trial 43 finished with value: 0.9349166666666666 and parameters: {'n_estimators': 259, 'learning_rate': 0.13963711663036193, 'max_depth': 7, 'subsample': 0.9018958611666094, 'min_samples_split': 6, 'min_samples_leaf': 19}. Best is trial 42 with value: 0.9358888888888889.
# [I 2025-12-08 18:27:56,880] Trial 44 finished with value: 0.9353611111111112 and parameters: {'n_estimators': 258, 'learning_rate': 0.13839259292396988, 'max_depth': 7, 'subsample': 0.8920859017074075, 'min_samples_split': 6, 'min_samples_leaf': 19}. Best is trial 42 with value: 0.9358888888888889.
# [I 2025-12-08 18:29:08,543] Trial 45 finished with value: 0.93375 and parameters: {'n_estimators': 302, 'learning_rate': 0.13908538441917506, 'max_depth': 7, 'subsample': 0.8781295543948898, 'min_samples_split': 9, 'min_samples_leaf': 19}. Best is trial 42 with value: 0.9358888888888889.
# [I 2025-12-08 18:30:33,820] Trial 46 finished with value: 0.9339999999999998 and parameters: {'n_estimators': 300, 'learning_rate': 0.18065798060462362, 'max_depth': 7, 'subsample': 0.7993561772434127, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 42 with value: 0.9358888888888889.
# [I 2025-12-08 18:31:38,112] Trial 47 finished with value: 0.9352777777777778 and parameters: {'n_estimators': 189, 'learning_rate': 0.0932819881512386, 'max_depth': 8, 'subsample': 0.9006622882798981, 'min_samples_split': 6, 'min_samples_leaf': 19}. Best is trial 42 with value: 0.9358888888888889.
# [I 2025-12-08 18:32:39,501] Trial 48 finished with value: 0.9344722222222223 and parameters: {'n_estimators': 188, 'learning_rate': 0.09940330065312013, 'max_depth': 8, 'subsample': 0.8513163202786257, 'min_samples_split': 5, 'min_samples_leaf': 19}. Best is trial 42 with value: 0.9358888888888889.
# [I 2025-12-08 18:34:00,411] Trial 49 finished with value: 0.9330555555555556 and parameters: {'n_estimators': 209, 'learning_rate': 0.2566020920945596, 'max_depth': 9, 'subsample': 0.8931969384415606, 'min_samples_split': 6, 'min_samples_leaf': 16}. Best is trial 42 with value: 0.9358888888888889.
# Лучшие параметры: {'n_estimators': 254, 'learning_rate': 0.09679919387889922, 'max_depth': 7, 'subsample': 0.8907630149846777, 'min_samples_split': 5, 'min_samples_leaf': 19}
# Лучшая accuracy: 0.9358888888888889
# 2025/12/08 18:34:36 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Логирование модели GradBoost завершено.

# %% [markdown]
# ### KNN

# %%
def objective_knn(trial, X, y):
    params = {
        "n_neighbors": trial.suggest_int("n_neighbors", 1, 50),
        "weights": trial.suggest_categorical("weights", ["uniform", "distance"]),
        "p": trial.suggest_int("p", 1, 2),  # 1=manhattan, 2=euclidean
        "leaf_size": trial.suggest_int("leaf_size", 10, 100),
    }

    model = KNeighborsClassifier(**params)

    score = cross_val_score(model, X, y, cv=3, scoring="accuracy").mean()
    return score

study = optuna.create_study(direction="maximize")
study.optimize(lambda trial: objective_knn(trial, X_train, y_train), n_trials=50)

print(f"Лучшие параметры: {study.best_params}")
print(f"Лучшая accuracy: {study.best_value}")

mlflow_save_model_metrics("KNN", KNeighborsClassifier, study.best_params)
# Out:
# [I 2025-12-08 18:34:41,683] A new study created in memory with name: no-name-7bce7e81-3526-4dd5-9538-d42ea6dd0220
# [I 2025-12-08 18:34:59,675] Trial 0 finished with value: 0.8989722222222222 and parameters: {'n_neighbors': 25, 'weights': 'distance', 'p': 1, 'leaf_size': 49}. Best is trial 0 with value: 0.8989722222222222.
# [I 2025-12-08 18:35:16,882] Trial 1 finished with value: 0.8996666666666666 and parameters: {'n_neighbors': 16, 'weights': 'distance', 'p': 1, 'leaf_size': 90}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:35:30,301] Trial 2 finished with value: 0.8879444444444444 and parameters: {'n_neighbors': 35, 'weights': 'distance', 'p': 2, 'leaf_size': 16}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:35:44,285] Trial 3 finished with value: 0.88475 and parameters: {'n_neighbors': 47, 'weights': 'distance', 'p': 2, 'leaf_size': 94}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:36:06,322] Trial 4 finished with value: 0.8955555555555555 and parameters: {'n_neighbors': 49, 'weights': 'distance', 'p': 1, 'leaf_size': 85}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:36:27,560] Trial 5 finished with value: 0.8967499999999999 and parameters: {'n_neighbors': 40, 'weights': 'distance', 'p': 1, 'leaf_size': 100}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:36:37,848] Trial 6 finished with value: 0.8868055555555555 and parameters: {'n_neighbors': 8, 'weights': 'uniform', 'p': 2, 'leaf_size': 76}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:36:51,735] Trial 7 finished with value: 0.8839166666666668 and parameters: {'n_neighbors': 38, 'weights': 'uniform', 'p': 2, 'leaf_size': 65}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:37:13,556] Trial 8 finished with value: 0.8932222222222221 and parameters: {'n_neighbors': 40, 'weights': 'uniform', 'p': 1, 'leaf_size': 61}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:37:35,507] Trial 9 finished with value: 0.8946111111111111 and parameters: {'n_neighbors': 34, 'weights': 'uniform', 'p': 1, 'leaf_size': 63}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:37:49,349] Trial 10 finished with value: 0.8954444444444444 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'p': 1, 'leaf_size': 38}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:38:07,236] Trial 11 finished with value: 0.8985 and parameters: {'n_neighbors': 21, 'weights': 'distance', 'p': 1, 'leaf_size': 43}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:38:24,561] Trial 12 finished with value: 0.8995555555555556 and parameters: {'n_neighbors': 19, 'weights': 'distance', 'p': 1, 'leaf_size': 39}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:38:42,238] Trial 13 finished with value: 0.8996388888888888 and parameters: {'n_neighbors': 17, 'weights': 'distance', 'p': 1, 'leaf_size': 27}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:38:59,475] Trial 14 finished with value: 0.8990277777777776 and parameters: {'n_neighbors': 14, 'weights': 'distance', 'p': 1, 'leaf_size': 20}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:39:09,399] Trial 15 finished with value: 0.8635833333333333 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 1, 'leaf_size': 27}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:39:29,782] Trial 16 finished with value: 0.8990277777777776 and parameters: {'n_neighbors': 14, 'weights': 'distance', 'p': 1, 'leaf_size': 10}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:39:41,865] Trial 17 finished with value: 0.8893333333333334 and parameters: {'n_neighbors': 30, 'weights': 'distance', 'p': 2, 'leaf_size': 76}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:39:59,485] Trial 18 finished with value: 0.8962222222222223 and parameters: {'n_neighbors': 16, 'weights': 'uniform', 'p': 1, 'leaf_size': 32}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:40:17,824] Trial 19 finished with value: 0.8989722222222222 and parameters: {'n_neighbors': 25, 'weights': 'distance', 'p': 1, 'leaf_size': 53}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:40:26,273] Trial 20 finished with value: 0.8914444444444444 and parameters: {'n_neighbors': 9, 'weights': 'distance', 'p': 2, 'leaf_size': 75}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:40:43,867] Trial 21 finished with value: 0.8995555555555556 and parameters: {'n_neighbors': 19, 'weights': 'distance', 'p': 1, 'leaf_size': 29}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:41:01,094] Trial 22 finished with value: 0.8985 and parameters: {'n_neighbors': 21, 'weights': 'distance', 'p': 1, 'leaf_size': 41}. Best is trial 1 with value: 0.8996666666666666.
# [I 2025-12-08 18:41:17,361] Trial 23 finished with value: 0.8998333333333332 and parameters: {'n_neighbors': 12, 'weights': 'distance', 'p': 1, 'leaf_size': 23}. Best is trial 23 with value: 0.8998333333333332.
# [I 2025-12-08 18:41:25,207] Trial 24 finished with value: 0.8635833333333333 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'p': 1, 'leaf_size': 22}. Best is trial 23 with value: 0.8998333333333332.
# [I 2025-12-08 18:41:44,958] Trial 25 finished with value: 0.8998333333333334 and parameters: {'n_neighbors': 11, 'weights': 'distance', 'p': 1, 'leaf_size': 10}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:42:02,494] Trial 26 finished with value: 0.8983888888888888 and parameters: {'n_neighbors': 11, 'weights': 'uniform', 'p': 1, 'leaf_size': 16}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:42:17,732] Trial 27 finished with value: 0.8936944444444445 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'p': 1, 'leaf_size': 11}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:42:33,374] Trial 28 finished with value: 0.8998333333333332 and parameters: {'n_neighbors': 12, 'weights': 'distance', 'p': 1, 'leaf_size': 88}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:42:52,010] Trial 29 finished with value: 0.8989722222222222 and parameters: {'n_neighbors': 25, 'weights': 'distance', 'p': 1, 'leaf_size': 46}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:43:08,754] Trial 30 finished with value: 0.8998333333333332 and parameters: {'n_neighbors': 12, 'weights': 'distance', 'p': 1, 'leaf_size': 69}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:43:24,109] Trial 31 finished with value: 0.8998333333333332 and parameters: {'n_neighbors': 12, 'weights': 'distance', 'p': 1, 'leaf_size': 70}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:43:37,005] Trial 32 finished with value: 0.8936944444444445 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'p': 1, 'leaf_size': 84}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:43:46,432] Trial 33 finished with value: 0.8998333333333332 and parameters: {'n_neighbors': 12, 'weights': 'distance', 'p': 1, 'leaf_size': 57}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:43:53,844] Trial 34 finished with value: 0.8872777777777777 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 1, 'leaf_size': 51}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:44:09,087] Trial 35 finished with value: 0.8990277777777776 and parameters: {'n_neighbors': 14, 'weights': 'distance', 'p': 1, 'leaf_size': 85}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:44:19,077] Trial 36 finished with value: 0.8924722222222222 and parameters: {'n_neighbors': 10, 'weights': 'distance', 'p': 2, 'leaf_size': 97}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:44:37,970] Trial 37 finished with value: 0.8986388888888889 and parameters: {'n_neighbors': 28, 'weights': 'distance', 'p': 1, 'leaf_size': 91}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:44:52,737] Trial 38 finished with value: 0.8971111111111112 and parameters: {'n_neighbors': 8, 'weights': 'distance', 'p': 1, 'leaf_size': 71}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:45:00,725] Trial 39 finished with value: 0.8885277777777777 and parameters: {'n_neighbors': 22, 'weights': 'uniform', 'p': 2, 'leaf_size': 18}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:45:10,878] Trial 40 finished with value: 0.8996666666666666 and parameters: {'n_neighbors': 16, 'weights': 'distance', 'p': 1, 'leaf_size': 83}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:45:21,771] Trial 41 finished with value: 0.8998333333333334 and parameters: {'n_neighbors': 11, 'weights': 'distance', 'p': 1, 'leaf_size': 69}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:45:30,836] Trial 42 finished with value: 0.8954444444444444 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'p': 1, 'leaf_size': 57}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:45:40,159] Trial 43 finished with value: 0.8998333333333332 and parameters: {'n_neighbors': 12, 'weights': 'distance', 'p': 1, 'leaf_size': 65}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:45:50,325] Trial 44 finished with value: 0.8995277777777778 and parameters: {'n_neighbors': 18, 'weights': 'distance', 'p': 1, 'leaf_size': 70}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:46:02,405] Trial 45 finished with value: 0.8955833333333333 and parameters: {'n_neighbors': 14, 'weights': 'uniform', 'p': 1, 'leaf_size': 80}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:46:24,423] Trial 46 finished with value: 0.895888888888889 and parameters: {'n_neighbors': 45, 'weights': 'distance', 'p': 1, 'leaf_size': 14}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:46:37,698] Trial 47 finished with value: 0.8946666666666667 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1, 'leaf_size': 89}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:46:48,346] Trial 48 finished with value: 0.8858333333333333 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1, 'leaf_size': 61}. Best is trial 25 with value: 0.8998333333333334.
# [I 2025-12-08 18:47:06,283] Trial 49 finished with value: 0.89875 and parameters: {'n_neighbors': 23, 'weights': 'distance', 'p': 1, 'leaf_size': 100}. Best is trial 25 with value: 0.8998333333333334.
# Лучшие параметры: {'n_neighbors': 11, 'weights': 'distance', 'p': 1, 'leaf_size': 10}
# Лучшая accuracy: 0.8998333333333334
# 2025/12/08 18:47:11 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Логирование модели KNN завершено.

# %% [markdown]
# ### SVC

# %%
def objective_svc(trial, X, y):
    params = {
        "C": trial.suggest_float("C", 1e-4, 100.0, log=True),
        "kernel": trial.suggest_categorical("kernel", ["linear", "rbf", "poly"]),
        "gamma": trial.suggest_categorical("gamma", ["scale", "auto"]),
        "degree": trial.suggest_int("degree", 2, 5),
        "probability": True
    }

    model = SVC(**params)

    score = cross_val_score(model, X, y, cv=3, scoring="accuracy").mean()
    return score

study = optuna.create_study(direction="maximize")
study.optimize(lambda trial: objective_svc(trial, X_train, y_train), n_trials=5)

print(f"Лучшие параметры: {study.best_params}")
print(f"Лучшая accuracy: {study.best_value}")

mlflow_save_model_metrics("SVC", SVC, study.best_params)
# Out:
# [I 2025-12-08 19:24:24,378] A new study created in memory with name: no-name-317c71f6-9ef9-4797-88e4-611cd0dc45d6
# [I 2025-12-08 19:27:03,386] Trial 0 finished with value: 0.7778333333333333 and parameters: {'C': 0.00024185217586091245, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 4}. Best is trial 0 with value: 0.7778333333333333.
# [I 2025-12-08 19:28:09,918] Trial 1 finished with value: 0.8939722222222222 and parameters: {'C': 0.08254049571596378, 'kernel': 'poly', 'gamma': 'scale', 'degree': 3}. Best is trial 1 with value: 0.8939722222222222.
# [I 2025-12-08 19:29:41,111] Trial 2 finished with value: 0.7871666666666667 and parameters: {'C': 0.00014686743147630395, 'kernel': 'linear', 'gamma': 'auto', 'degree': 5}. Best is trial 1 with value: 0.8939722222222222.
# [I 2025-12-08 19:32:02,791] Trial 3 finished with value: 0.9067777777777778 and parameters: {'C': 30.256852919878668, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 2}. Best is trial 3 with value: 0.9067777777777778.
# [I 2025-12-08 19:33:09,796] Trial 4 finished with value: 0.8904722222222222 and parameters: {'C': 0.0034438556818262075, 'kernel': 'linear', 'gamma': 'scale', 'degree': 4}. Best is trial 3 with value: 0.9067777777777778.
# Лучшие параметры: {'C': 30.256852919878668, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 2}
# Лучшая accuracy: 0.9067777777777778
# 2025/12/08 19:33:39 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Логирование модели SVC завершено.
